# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
import numpy as np

LABELS = ["No", "To some extent", "Yes"]
TASKS = ["Mistake_Identification", "Mistake_Location", "Providing_Guidance", "Actionability"]

def to_label_name(idx):
    return LABELS[idx] if isinstance(idx, int) else idx

def convert_to_lenient(y):
    return ["Yes" if label in ["Yes", "To some extent"] else "No" for label in y]

def plot_conf_matrix(y_true, y_pred, labels, title, ax):
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels, ax=ax)
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")
    ax.set_title(title)

def evaluate_predictions(preds_dict, labels_dict):
    print("="*80)
    print("EXACT (3-CLASS) EVALUATION")
    print("="*80)

    fig_3, axs_3 = plt.subplots(2, 2, figsize=(14, 10))
    axs_3 = axs_3.flatten()

    for i, task in enumerate(TASKS):
        y_pred = [to_label_name(p) for p in preds_dict[task]]
        y_true = [to_label_name(t) for t in labels_dict[task]]

        acc = accuracy_score(y_true, y_pred)
        f1 = f1_score(y_true, y_pred, average='macro')

        print(f"\nTask: {task}")
        print(f"Accuracy: {acc:.4f}")
        print(f"Macro F1: {f1:.4f}")
        print(classification_report(y_true, y_pred, target_names=LABELS, digits=3))

        plot_conf_matrix(y_true, y_pred, LABELS, f"{task} (3-Class)", axs_3[i])

    plt.tight_layout()
    plt.show()

    print("="*80)
    print("LENIENT (2-CLASS) EVALUATION")
    print("="*80)

    fig_2, axs_2 = plt.subplots(2, 2, figsize=(14, 10))
    axs_2 = axs_2.flatten()

    for i, task in enumerate(TASKS):
        y_pred = convert_to_lenient([to_label_name(p) for p in preds_dict[task]])
        y_true = convert_to_lenient([to_label_name(t) for t in labels_dict[task]])

        acc = accuracy_score(y_true, y_pred)
        f1 = f1_score(y_true, y_pred, pos_label='Yes', average='binary')

        print(f"\nTask: {task}")
        print(f"Accuracy: {acc:.4f}")
        print(f"Macro F1: {f1:.4f}")
        print(classification_report(y_true, y_pred, target_names=['No', 'Yes'], digits=3))

        plot_conf_matrix(y_true, y_pred, ['No', 'Yes'], f"{task} (2-Class)", axs_2[i])

    plt.tight_layout()
    plt.show()

# %%
import os
os.environ["TRANSFORMERS_NO_TF"] = "1"
os.environ["TRANSFORMERS_NO_FLAX"] = "1"

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from transformers import AutoTokenizer, AutoModel, get_scheduler
from torch.optim import AdamW
from sklearn.metrics import classification_report, f1_score
from sklearn.utils.class_weight import compute_class_weight
import json
import numpy as np
from tqdm import tqdm
from typing import List
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# --- Constants ---
MODEL_NAME = 'distilbert-base-uncased'
NUM_LABELS = 3
LABELS = ["No", "To some extent", "Yes"]
LABEL2ID = {label: i for i, label in enumerate(LABELS)}
ID2LABEL = {v: k for k, v in LABEL2ID.items()}
TASKS = ['Mistake_Identification', 'Mistake_Location', 'Providing_Guidance', 'Actionability']

# --- Dataset Loader ---
class TutorDataset(Dataset):
    def __init__(self, data: List[dict], tokenizer, max_length=512):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        text = item['conversation_history'] + "\nTutor Response: " + item['response']
        encoding = self.tokenizer(text, truncation=True, padding='max_length', max_length=self.max_length, return_tensors='pt')

        labels = {task: LABEL2ID[item['annotation'][task]] for task in TASKS}

        return {
            'input_ids': encoding['input_ids'].squeeze(),
            'attention_mask': encoding['attention_mask'].squeeze(),
            'labels': torch.tensor([labels[task] for task in TASKS], dtype=torch.long)
        }

# --- Model Definition ---
class PedagogicalModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = AutoModel.from_pretrained(MODEL_NAME)
        self.dropout = nn.Dropout(0.2)
        self.heads = nn.ModuleDict({task: nn.Linear(self.encoder.config.hidden_size, NUM_LABELS) for task in TASKS})

    def forward(self, input_ids, attention_mask):
        outputs = self.encoder(input_ids=input_ids, attention_mask=attention_mask)
        pooled = self.dropout(outputs.last_hidden_state[:, 0])
        return {task: head(pooled) for task, head in self.heads.items()}

# --- Focal Loss ---
class FocalLoss(nn.Module):
    def __init__(self, alpha=1.0, gamma=2.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss
        return focal_loss.mean()

# --- Evaluation ---
def evaluate_model(model, dataloader):
    model.eval()
    device = next(model.parameters()).device
    y_true = {task: [] for task in TASKS}
    y_pred = {task: [] for task in TASKS}

    with torch.no_grad():
        for batch in dataloader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels']

            outputs = model(input_ids, attention_mask)
            for i, task in enumerate(TASKS):
                logits = outputs[task].cpu()
                preds = torch.argmax(logits, dim=-1)
                y_pred[task].extend(preds.tolist())
                y_true[task].extend(labels[:, i].tolist())

    return y_true, y_pred

# --- Training Function ---
def train_model(model, train_loader, val_loader, epochs=15, lr=4e-5, use_focal=True, save_dir="models"):
    import os
    os.makedirs(save_dir, exist_ok=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    optimizer = AdamW(model.parameters(), lr=lr)
    scheduler = get_scheduler("linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=len(train_loader) * epochs)

    loss_fn = FocalLoss() if use_focal else nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for batch in tqdm(train_loader, desc=f"Training Epoch {epoch+1}"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask)
            loss = sum([loss_fn(outputs[task], labels[:, i]) for i, task in enumerate(TASKS)])
            loss.backward()
            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()
            total_loss += loss.item()

        print(f"Epoch {epoch+1} Loss: {total_loss / len(train_loader):.4f}")

        # 🔒 Save model after each epoch
        torch.save(model.state_dict(), os.path.join(save_dir, f"model.pt"))

    # Evaluate after all epochs (once per tutor)
    y_true, y_pred = evaluate_model(model, val_loader)
    print("\nFINAL EVALUATION ON VALIDATION SET")
    evaluate_predictions(y_pred, y_true)
    return y_true, y_pred

# --- Data Preprocessing ---
def load_json_dataset(path):
    with open(path, 'r') as f:
        raw = json.load(f)
    samples = []
    for conv in raw:
        for name, info in conv['tutor_responses'].items():
            samples.append({
                'conversation_id': conv['conversation_id'],
                'conversation_history': conv['conversation_history'],
                'response': info['response'],
                'annotation': info['annotation']
            })
    return samples

# --- Main Execution ---
if __name__ == '__main__':
    from sklearn.model_selection import train_test_split

    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    data = load_json_dataset('/kaggle/input/ai-tutor/assignment_3_ai_tutors_dataset.json')
    train_data, val_data = train_test_split(data, test_size=0.2, random_state=42)

    train_ds = TutorDataset(train_data, tokenizer)
    val_ds = TutorDataset(val_data, tokenizer)

    train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=32)

    model = PedagogicalModel()
    y_true_dict, y_pred_dict = train_model(model, train_loader, val_loader, epochs=15, lr=4e-5, use_focal=True)

    # evaluate_predictions(y_pred_dict, y_true_dict)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# 2025-04-24 17:21:39.457753: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745515299.659154      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745515299.713934      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Training Epoch 1: 100%|██████████| 248/248 [01:14<00:00,  3.31it/s]
# Epoch 1 Loss: 1.4827
# Training Epoch 2: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 2 Loss: 1.1526
# Training Epoch 3: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 3 Loss: 0.9686
# Training Epoch 4: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 4 Loss: 0.7775
# Training Epoch 5: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 5 Loss: 0.5990
# Training Epoch 6: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 6 Loss: 0.4339
# Training Epoch 7: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 7 Loss: 0.3094
# Training Epoch 8: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 8 Loss: 0.2297
# Training Epoch 9: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 9 Loss: 0.1718
# Training Epoch 10: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 10 Loss: 0.1252
# Training Epoch 11: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 11 Loss: 0.0965
# Training Epoch 12: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 12 Loss: 0.0826
# Training Epoch 13: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 13 Loss: 0.0673
# Training Epoch 14: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 14 Loss: 0.0589
# Training Epoch 15: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 15 Loss: 0.0479
# Training Epoch 16: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 16 Loss: 0.0406
# Training Epoch 17: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 17 Loss: 0.0352
# Training Epoch 18: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 18 Loss: 0.0323
# Training Epoch 19: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 19 Loss: 0.0284
# Training Epoch 20: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 20 Loss: 0.0256
# Training Epoch 21: 100%|██████████| 248/248 [01:14<00:00,  3.34it/s]
# Epoch 21 Loss: 0.0224
# Training Epoch 22: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 22 Loss: 0.0234
# Training Epoch 23: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 23 Loss: 0.0218
# Training Epoch 24: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 24 Loss: 0.0185
# Training Epoch 25: 100%|██████████| 248/248 [01:14<00:00,  3.35it/s]
# Epoch 25 Loss: 0.0183
#
# FINAL EVALUATION ON VALIDATION SET
# ================================================================================
# EXACT (3-CLASS) EVALUATION
# ================================================================================
#
# Task: Mistake_Identification
# Accuracy: 0.8770
# Macro F1: 0.6761
#                 precision    recall  f1-score   support
#
#             No      0.810     0.701     0.752        67
# To some extent      0.474     0.273     0.346        33
#            Yes      0.905     0.957     0.930       396
#
#       accuracy                          0.877       496
#      macro avg      0.730     0.644     0.676       496
#   weighted avg      0.863     0.877     0.867       496
#
#
# Task: Mistake_Location
# Accuracy: 0.7440
# Macro F1: 0.5488
#                 precision    recall  f1-score   support
#
#             No      0.689     0.592     0.636       142
# To some extent      0.227     0.143     0.175        35
#            Yes      0.795     0.878     0.835       319
#
#       accuracy                          0.744       496
#      macro avg      0.570     0.537     0.549       496
#   weighted avg      0.725     0.744     0.731       496
#
#
# Task: Providing_Guidance
# Accuracy: 0.6754
# Macro F1: 0.5894
#                 precision    recall  f1-score   support
#
#             No      0.674     0.487     0.566       119
# To some extent      0.529     0.346     0.419       104
#            Yes      0.705     0.883     0.784       273
#
#       accuracy                          0.675       496
#      macro avg      0.636     0.572     0.589       496
#   weighted avg      0.661     0.675     0.655       496
#
#
# Task: Actionability
# Accuracy: 0.7218
# Macro F1: 0.6394
#                 precision    recall  f1-score   support
#
#             No      0.845     0.682     0.755       176
# To some extent      0.403     0.352     0.376        71
#            Yes      0.729     0.855     0.787       249
#
#       accuracy                          0.722       496
#      macro avg      0.659     0.630     0.639       496
#   weighted avg      0.724     0.722     0.717       496
# ================================================================================
# LENIENT (2-CLASS) EVALUATION
# ================================================================================
#
# Task: Mistake_Identification
# Accuracy: 0.9375
# Macro F1: 0.9642
#               precision    recall  f1-score   support
#
#           No      0.810     0.701     0.752        67
#          Yes      0.954     0.974     0.964       429
#
#     accuracy                          0.938       496
#    macro avg      0.882     0.838     0.858       496
# weighted avg      0.935     0.938     0.936       496
#
#
# Task: Mistake_Location
# Accuracy: 0.8065
# Macro F1: 0.8681
#               precision    recall  f1-score   support
#
#           No      0.689     0.592     0.636       142
#          Yes      0.845     0.893     0.868       354
#
#     accuracy                          0.806       496
#    macro avg      0.767     0.742     0.752       496
# weighted avg      0.800     0.806     0.802       496
#
#
# Task: Providing_Guidance
# Accuracy: 0.8206
# Macro F1: 0.8869
#               precision    recall  f1-score   support
#
#           No      0.674     0.487     0.566       119
#          Yes      0.851     0.926     0.887       377
#
#     accuracy                          0.821       496
#    macro avg      0.763     0.707     0.726       496
# weighted avg      0.809     0.821     0.810       496
#
#
# Task: Actionability
# Accuracy: 0.8427
# Macro F1: 0.8843
#               precision    recall  f1-score   support
#
#           No      0.845     0.682     0.755       176
#          Yes      0.842     0.931     0.884       320
#
#     accuracy                          0.843       496
#    macro avg      0.843     0.807     0.819       496
# weighted avg      0.843     0.843     0.838       496
